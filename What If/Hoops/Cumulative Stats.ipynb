# %%
import pandas as pd
import numpy as np
from itertools import repeat
from urllib.request import urlopen
import ssl
import time
import urllib.request

# %%
aad = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/Andre_and_Deandre.csv')
aad['Team'] = 'Andre and Deandre'
aad
# Out:
#                     Name  GP  GS   Min   Pts  FGM   FGA  3PM  3PA  FTM  ...  \
# 0   15-16 DeAndre Jordan  82  82  2676  1198  538   786    1    3  121  ...
# 1    95-96 Dennis Rodman  82  77  2169   437  192   390    5   33   48  ...
# 2     18-19 LeBron James  82  54  1996  1355  547  1124  102  305  159  ...
# 3    22-23 Stephen Curry  82  61  1992  1523  527  1166  254  657  215  ...
# 4    93-94 Nate McMillan  82  79  1962   419  171   437   47  136   30  ...
# 5     20-21 LeBron James  82  27  1751  1307  496   997  124  350  191  ...
# 6    17-18 Stephen Curry  82  21  1680  1389  460   925  238  530  231  ...
# 7    94-95 Dennis Rodman  82   5  1621   413  174   322    0    6   65  ...
# 8    95-96 Nate McMillan  82   3  1310   273   97   269   45  124   34  ...
# 9   12-13 Andre Drummond  82   0  1306   543  252   430    1    3   38  ...
# 10    96-97 Kevin Gamble  82   1   981   290  107   289   52  117   24  ...
# ...

# %%
aotc2 = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/aotc2.csv')
aotc2['Team'] = 'Attack of the Clones: Part 2'
aotc2
# Out:
#                        Name  GP  GS   Min   Pts  FGM   FGA  3PM  3PA  FTM  \
# 0      21-22 Christian Wood  82  63  2131  1133  440   955  110  334  143
# 1        16-17 Nikola Jokic  82  52  2095  1179  490   905   31  135  168
# 2       22-23 Stephen Curry  82  48  1989  1598  548  1146  265  615  237
# 3       93-94 Nate McMillan  82  60  1926   404  159   412   44  136   42
# 4   21-22 Mitchell Robinson  82  45  1885   702  320   441    0    6   62
# 5   19-20 Mitchell Robinson  82  37  1800   790  361   499    1    1   67
# 6    21-22 Domantas Sabonis  82  30  1685   888  348   599   40  104  152
# 7       17-18 Stephen Curry  82  34  1673  1372  482   987  234  541  174
# 8      20-21 Christian Wood  82  19  1544   918  375   731   87  221   81
# 9       95-96 Nate McMillan  82  22  1298   267   94   263   43  121   36
# 10    05-06 DerMarr Johnson  82   0   943   330  114   278   50  137   52
# 11   21-22 Lance Stephenson  82   0   768   339  135   305   29   81   40
#
# ...

# %%
iwi = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/IWI.csv')
iwi['Team'] = 'I WANT IGUODALA'
iwi
# Out:
#                        Name  GP  GS   Min   Pts  FGM   FGA  3PM  3PA  FTM  \
# 0      15-16 DeAndre Jordan  82  82  2725  1137  490   715    0    3  157
# 1       22-23 Stephen Curry  82  44  2004  1512  534  1145  267  640  177
# 2        18-19 LeBron James  82  51  1995  1397  541  1122   98  302  217
# 3       93-94 Nate McMillan  82  82  1963   474  186   417   47  122   55
# 4   21-22 Mitchell Robinson  82  53  1906   632  290   391    0    0   52
# 5   19-20 Mitchell Robinson  82  29  1820   795  361   505    0    0   73
# 6        20-21 LeBron James  82  30  1781  1271  496  1025  107  320  172
# 7       17-18 Stephen Curry  82  38  1690  1308  454   950  225  540  175
# 8       95-96 Nate McMillan  82   0  1302   313  112   276   49  126   40
# 9        06-07 Reggie Evans  82   0  1164   399  163   294    0    1   73
# 10        12-13 Luke Walton  80   1   926   179   72   214   17   75   18
# 11     19-20 Andre Iguodala  82   0   504   125   51   124   15   64    8
#
# ...

# %%
mj = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/MJ.csv')
mj['Team'] = 'Can Michael Win a WIS Championship?'
mj
# Out:
#                        Name  GP  GS   Min   Pts   FGM   FGA  3PM  3PA  FTM  \
# 0      87-88 Michael Jordan  82  82  3419  2775  1127  2209    5   69  516
# 1       97-98 Dennis Rodman  82  81  2936   431   185   431    4   17   57
# 2       09-10 Dwight Howard  82  80  2909  1696   701  1108    1   12  293
# 3          07-08 Steve Nash  82  80  2832  1464   523  1069  200  413  218
# 4         14-15 Kyle Korver  82  65  2474   881   286   642  216  473   93
# 5          22-23 Sam Hauser  82  15  1323   470   157   365  117  296   39
# 6   21-22 Tyrese Haliburton  82   0   980   448   167   347   63  140   51
# 7      18-19 Tyson Chandler  82   1   899   192    82   143    0    2   28
# 8        16-17 JaVale McGee  82   2   761   530   240   359    0    4   50
# 9         10-11 Luke Walton  81   2   585   103    35   136   11   50   22
# 10          13-14 Gal Mekel  80   2   369    86    34   119    6   27   12
# ...

# %%
tcc = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/TCC.csv')
tcc['Team'] = 'Tyson Chicken Curry'
tcc
# Out:
#                       Name  GP  GS   Min   Pts  FGM   FGA  3PM  3PA  FTM  ...  \
# 0   67-68 Wilt Chamberlain  82  82  3934  1928  871  1445    1    4  185  ...
# 1      97-98 Dennis Rodman  82  81  2905   450  190   437    3   30   67  ...
# 2      22-23 Stephen Curry  82  49  1986  1635  577  1186  270  629  211  ...
# 3       18-19 LeBron James  82  50  1969  1426  563  1152  108  316  192  ...
# 4       20-21 LeBron James  82  30  1755  1286  495  1011  111  319  185  ...
# 5   21-22 Matisse Thybulle  82  44  1712   378  144   322   46  155   44  ...
# 6      17-18 Stephen Curry  82  33  1659  1341  469   938  208  500  195  ...
# 7   20-21 Matisse Thybulle  82  36  1506   266   97   269   48  170   24  ...
# 8     18-19 Tyson Chandler  80   0   792   165   67   108    0    3   31  ...
# 9   22-23 Matisse Thybulle  82   2   638   164   58   128   24   69   24  ...
# 10       10-11 Luke Walton  80   2   560   114   45   149   10   39   14  ...
# ...

# %%
scdb = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/SC&DB.csv')
scdb['Team'] = 'Serge Chewbacca Meets Dark Brandan'
scdb
# Out:
#                        Name  GP    GS     Min   Pts  FGM   FGA  3PM  3PA  FTM  \
# 0    67-68 Wilt Chamberlain  82  82.0  3905.0  1832  821  1396    0    4  190
# 1         11-12 Serge Ibaka  82  82.0  2273.0   787  346   687    0    3   95
# 2      20-21 Michael Porter  82  48.0  2222.0  1285  478   949  180  421  149
# 3       22-23 Stephen Curry  82  51.0  1974.0  1543  527  1137  258  634  231
# 4       93-94 Nate McMillan  82  67.0  1930.0   418  170   386   46  117   32
# 5      22-23 Michael Porter  82  31.0  1819.0   985  366   787  168  419   85
# 6       17-18 Stephen Curry  82  31.0  1646.0  1298  442   937  202  528  212
# 7       95-96 Nate McMillan  82  10.0  1288.0   297  111   298   49  145   26
# 8   09-10 DeShawn Stevenson  82   5.0  1011.0   136   47   203   14  103   28
# 9      12-13 Chris Andersen  82   0.0   632.0   254   98   172    4    6   54
# 10     14-15 Brandan Wright  80   0.0   503.0   244  112   167    0    1   20
# ...

# %%
skfs = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/SKFS.csv')
skfs['Team'] = 'Steve Kerrs Freak Show'
skfs
# Out:
#                            Name  GP    GS     Min   Pts  FGM   FGA  3PM  3PA  \
# 0   18-19 Giannis Antetokounmpo  82  68.0  2405.0  1916  768  1366   45  198
# 1   20-21 Giannis Antetokounmpo  82  53.0  2345.0  1827  738  1375   73  233
# 2   21-22 Giannis Antetokounmpo  82  43.0  2254.0  1961  781  1436   66  228
# 3              95-96 Steve Kerr  82  38.0  1967.0   666  236   513  116  248
# 4       21-22 Mitchell Robinson  82  51.0  1905.0   614  276   380    0    0
# 5              96-97 Steve Kerr  82  44.0  1901.0   664  253   510  107  239
# 6       19-20 Mitchell Robinson  82  31.0  1807.0   772  343   503    0    4
# 7        21-22 Matisse Thybulle  82  66.0  1724.0   411  165   342   47  155
# 8        20-21 Matisse Thybulle  82  16.0  1514.0   259  102   287   43  154
# 9       09-10 DeShawn Stevenson  82   0.0   927.0   130   44   209   16  109
# 10             80-81 John Duren  79   0.0   506.0    74   32   130    0    3
# ...

# %%
bb = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/BBGSW.csv')
bb['Team'] = 'Brick Brickowski'
bb
# Out:
#                       Name  GP    GS     Min   Pts  FGM   FGA  3PM  3PA  FTM  \
# 0   72-73 Wilt Chamberlain  82  82.0  3607.0  1114  507   690    0    4  100
# 1       17-18 Kevin Durant  82  56.0  2362.0  1813  679  1293  189  428  266
# 2     20-21 Draymond Green  82  67.0  2292.0   560  217   484   40  144   86
# 3      22-23 Stephen Curry  82  47.0  1972.0  1582  549  1104  272  610  212
# 4       21-22 Kevon Looney  82  69.0  1762.0   487  214   431    0    1   59
# 5      17-18 Stephen Curry  82  33.0  1658.0  1428  493   957  225  528  217
# 6       18-19 Kevon Looney  82  12.0  1513.0   559  254   442    1   15   50
# 7       22-23 Kevin Durant  81  24.0  1428.0  1130  436   789   79  198  179
# 8     21-22 Draymond Green  82  14.0  1357.0   399  164   330   20   64   51
# 9    08-09 Fabricio Oberto  79   2.0   769.0   166   72   175    0    6   22
# 10        80-81 John Duren  72   2.0   579.0   101   45   157    0    1   11
# ...

# %%
pj = pd.read_csv(f'/Users/calebsmith/Library/Mobile Documents/com~apple~CloudDocs/Documents/What If/Hoops/Teams/PJ.csv')
pj['Team'] = 'Peter Jackson'
pj
# Out:
#                        Name  GP    GS     Min   Pts  FGM   FGA  3PM  3PA  FTM  \
# 0        78-79 Moses Malone  82  82.0  3499.0  1988  796  1534   15   57  381
# 1       94-95 John Stockton  82  82.0  2930.0  1263  472   900  114  270  205
# 2       88-89 Dennis Rodman  82  73.0  2257.0   824  366   609    4   20   88
# 3       22-23 Stephen Curry  82  59.0  2000.0  1547  517  1096  265  603  248
# 4    21-22 Robert Covington  82  71.0  1983.0   612  211   515  128  326   62
# 5       17-18 Stephen Curry  82  23.0  1675.0  1198  419   891  195  482  165
# 6    18-19 Robert Covington  82  11.0  1236.0   403  137   361   73  210   56
# 7        22-23 Steven Adams  82   9.0  1161.0   438  197   354    0    4   44
# 8   09-10 DeShawn Stevenson  82   0.0   934.0   159   48   173   28   95   35
# 9      22-23 Andre Drummond  82   0.0   901.0   456  202   351    1    2   51
# 10        14-15 Rajon Rondo  82   0.0   727.0   209   93   237   11   42   12
# ...

# %%
all_seasons = pd.concat([aad, aotc2, iwi, mj, tcc, scdb, skfs, bb, pj])
all_seasons
# Out:
#                        Name  GP    GS     Min   Pts  FGM   FGA  3PM  3PA  FTM  \
# 0      15-16 DeAndre Jordan  82  82.0  2676.0  1198  538   786    1    3  121
# 1       95-96 Dennis Rodman  82  77.0  2169.0   437  192   390    5   33   48
# 2        18-19 LeBron James  82  54.0  1996.0  1355  547  1124  102  305  159
# 3       22-23 Stephen Curry  82  61.0  1992.0  1523  527  1166  254  657  215
# 4       93-94 Nate McMillan  82  79.0  1962.0   419  171   437   47  136   30
# ..                      ...  ..   ...     ...   ...  ...   ...  ...  ...  ...
# 7        22-23 Steven Adams  82   9.0  1161.0   438  197   354    0    4   44
# 8   09-10 DeShawn Stevenson  82   0.0   934.0   159   48   173   28   95   35
# 9      22-23 Andre Drummond  82   0.0   901.0   456  202   351    1    2   51
# 10        14-15 Rajon Rondo  82   0.0   727.0   209   93   237   11   42   12
# 11          20-21 Josh Hall  79   0.0   423.0   122   51   158    6   50   14
#
# ...

# %% [markdown]
# # Analysis

# %%
all_seasons['PPM'] = all_seasons['Pts'] / all_seasons['Min']
all_seasons['ORPM'] = all_seasons['OReb'] / all_seasons['Min']
all_seasons['RPM'] = all_seasons['Reb'] / all_seasons['Min']
all_seasons['APM'] = all_seasons['Ast'] / all_seasons['Min']
all_seasons['BPM'] = all_seasons['Blk'] / all_seasons['Min']
all_seasons['SPM'] = all_seasons['Stl'] / all_seasons['Min']

# %%
all_seasons.columns
# Out:
# Index(['Name', 'GP', 'GS', 'Min', 'Pts', 'FGM', 'FGA', '3PM', '3PA', 'FTM',
#        'FTA', 'OReb', 'Reb', 'Ast', 'TO', 'Stl', 'Blk', 'PF', '2PM', '2PA',
#        '2P%', '3P%', 'FG%', 'eFG', 'Team', 'PPM', 'ORPM', 'RPM', 'APM', 'BPM',
#        'SPM'],
#       dtype='object')

# %%
all_seasons.sort_values('PPM', ascending = False).head(10)
# Out:
#                           Name  GP    GS     Min   Pts   FGM   FGA  3PM  3PA  \
# 2  21-22 Giannis Antetokounmpo  82  43.0  2254.0  1961   781  1436   66  228
# 5          17-18 Stephen Curry  82  33.0  1658.0  1428   493   957  225  528
# 6          17-18 Stephen Curry  82  21.0  1680.0  1389   460   925  238  530
# 2          22-23 Stephen Curry  82  49.0  1986.0  1635   577  1186  270  629
# 7          17-18 Stephen Curry  82  34.0  1673.0  1372   482   987  234  541
# 0         87-88 Michael Jordan  82  82.0  3419.0  2775  1127  2209    5   69
# 6          17-18 Stephen Curry  82  33.0  1659.0  1341   469   938  208  500
# 2          22-23 Stephen Curry  82  48.0  1989.0  1598   548  1146  265  615
# 3          22-23 Stephen Curry  82  47.0  1972.0  1582   549  1104  272  610
# 0  18-19 Giannis Antetokounmpo  82  68.0  2405.0  1916   768  1366   45  198
#
#    FTM  ...        3P%        FG%        eFG  \
# 2  333  ...  28.947368  54.387187  56.685237
# ...
